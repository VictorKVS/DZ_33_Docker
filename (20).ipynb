# %% [markdown]
# ## **Домашнее задание**

# %% [markdown]
# > 1) Написать Dockerfile для проекта Django
# > 2) Создать и запустить контейнер
#
# Необходимо сдать Dockerfile, и 2 снимка экрана (работающий докер `docker ps -a` и работающее приложение)
